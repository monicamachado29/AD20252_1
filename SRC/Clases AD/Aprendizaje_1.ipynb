# %% [markdown]
# class Persona ():
#     def __init__():
#         pass
#     def caminar ():
#         print ("camina")

# %%
class Persona ():
    def __init__(self):
        pass
    def caminar (self):
        print ("camina")

# %%
persona=Persona()
persona.caminar()
# Out:
# camina
